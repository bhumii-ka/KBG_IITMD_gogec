# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ## Load Data Files

# %%
metadata_df = pd.read_csv('data/SDP.csv')
print(f"Loaded {len(metadata_df)} metadata records")
metadata_df.head()
# Out:
# Loaded 875 metadata records
#           id                                          cell_type  \
# 0  drug:3639  Bone marrow Sca+ SP hematopoeitic stem cells (...
# 1  drug:3499                            vastus lateralis muscle
# 2  drug:3292                               lymphoblastoid cells
# 3  drug:3638  Bone marrow Sca+ SP hematopoeitic stem cells (...
# 4  drug:3475                                              liver
#
#                                             ctrl_ids         curator  \
# 0                                  GSM26734|GSM26735          cadimo
# 1  GSM801199|GSM801201|GSM801202|GSM801204|GSM801...  MicrotaskManic
# 2                      GSM162898|GSM162900|GSM162903        garibr01
# 3                                  GSM26734|GSM26735          cadimo
# 4        GSM1273512|GSM1273513|GSM1273514|GSM1273515  MicrotaskManic
#
#       drug_name drugbank_id    geo_id organism  \
# 0  Fluorouracil     DB00544   GSE1559    mouse
# 1   Resveratrol     DB02709  GSE32357    human
# 2    Citalopram     DB00215   GSE7036    human
# 3  Fluorouracil     DB00544   GSE1559    mouse
# 4       Ethanol     DB00898  GSE52644    mouse
#
#                                             pert_ids  platform  pubchem_cid  \
# 0                                  GSM26744|GSM26745     GPL81       3385.0
# 1  GSM801198|GSM801200|GSM801203|GSM801205|GSM801...  GPL11532          NaN
# 2                      GSM162897|GSM162899|GSM162901    GPL570       2771.0
# 3                                  GSM26742|GSM26743     GPL81       3385.0
# 4        GSM1273500|GSM1273501|GSM1273502|GSM1273503   GPL1261        702.0
#
#                                             smiles  version
# 0                             C1=C(C(=O)NC(=O)N1)F      1.0
# 1                   Oc1ccc(cc1)/C=C/c1cc(O)cc(c1)O      1.0
# 2  CN(C)CCCC1(C2=C(CO1)C=C(C=C2)C#N)C3=CC=C(C=C3)F      1.0
# 3                             C1=C(C(=O)NC(=O)N1)F      1.0
# 4                                              CCO      1.0

# %%
with open('data/DP.json', 'r') as f:
    drug_data = json.load(f)

print(f"Loaded {len(drug_data)} drug perturbation records")
# Out:
# Loaded 875 drug perturbation records

# %% [markdown]
# ## Filter for Human Drugs

# %%
# Filter drugs where organism is 'human'
human_drugs = [drug for drug in drug_data if drug.get('organism', '').lower() == 'human']
print(f"Found {len(human_drugs)} human drug records")
# Out:
# Found 450 human drug records

# %% [markdown]
# ## Define Input Gene Arrays

# %%
# Input array 1: Up-regulated genes in disease
up_regulated_genes = [
    "LYZ",
    "CSRP3",
    "SNORD13"
]

# Input array 2: Down-regulated genes in disease
down_regulated_genes = [
    "RNU1-1",
    "GAPDH",
    "RPL8"
    

    
]

# %% [markdown]
# ## Match Genes with Drug Data

# %%
def match_genes_to_drugs(human_drugs, up_regulated_genes, down_regulated_genes):
    
    drug_aggregates = {}
    
    for drug in human_drugs:
        drug_name = drug.get('drug_name', 'Unknown')
        smiles = drug.get('smiles', 'N/A')
        cell_type = drug.get('cell_type', 'N/A')
        idx = drug.get('id', 'N/A')
        
        # Initialize drug entry if not exists
        if drug_name not in drug_aggregates:
            drug_aggregates[drug_name] = {
                'smiles': smiles,
                'up_reg_matches': [],
                'down_reg_matches': [],
                'cell_types': [],
                'drug_ids': []
            }
        
        # Collect cell types and drug IDs
        if cell_type not in drug_aggregates[drug_name]['cell_types']:
            drug_aggregates[drug_name]['cell_types'].append(cell_type)
        if idx not in drug_aggregates[drug_name]['drug_ids']:
            drug_aggregates[drug_name]['drug_ids'].append(idx)
        
        # Search up-regulated genes in drug's down_genes
        down_genes_dict = {gene[0]: gene[1] for gene in drug.get('down_genes', [])}
        for gene in up_regulated_genes:
            if gene in down_genes_dict:
                drug_aggregates[drug_name]['down_reg_matches'].append({
                    'gene': gene,
                    'score': down_genes_dict[gene]
                })
        
        # Search down-regulated genes in drug's up_genes
        up_genes_dict = {gene[0]: gene[1] for gene in drug.get('up_genes', [])}
        for gene in down_regulated_genes:
            if gene in up_genes_dict:
                drug_aggregates[drug_name]['up_reg_matches'].append({
                    'gene': gene,
                    'score': up_genes_dict[gene]
                })
    
    # Convert to results list
    results = []
    for drug_name, data in drug_aggregates.items():
        # Add down-regulation row if matches exist
        if data['down_reg_matches']:
            results.append({
                'drug_name': drug_name,
                'smiles': data['smiles'],
                'regulation_type': 'down',
                'matched_genes': ','.join([m['gene'] for m in data['down_reg_matches']]),
                'regulation_scores': ','.join([f"{m['score']:.4f}" for m in data['down_reg_matches']]),
                'avg_score': np.mean([m['score'] for m in data['down_reg_matches']]),
                'gene_count': len(data['down_reg_matches']),
                'drug_ids': ','.join(data['drug_ids']),
                'cell_types': ','.join(data['cell_types'])
            })
        
        # Add up-regulation row if matches exist
        if data['up_reg_matches']:
            results.append({
                'drug_name': drug_name,
                'smiles': data['smiles'],
                'regulation_type': 'up',
                'matched_genes': ','.join([m['gene'] for m in data['up_reg_matches']]),
                'regulation_scores': ','.join([f"{m['score']:.4f}" for m in data['up_reg_matches']]),
                'avg_score': np.mean([m['score'] for m in data['up_reg_matches']]),
                'gene_count': len(data['up_reg_matches']),
                'drug_ids': ','.join(data['drug_ids']),
                'cell_types': ','.join(data['cell_types'])
            })
    
    return results

# %%
# Execute matching
results = match_genes_to_drugs(human_drugs, up_regulated_genes, down_regulated_genes)
print(f"Found {len(results)} drug-regulation rows")
# Out:
# Found 152 drug-regulation rows

# %% [markdown]
# ## Generate Results Table

# %%
# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display results
if len(results_df) > 0:
    print(f"\nTotal rows: {len(results_df)}")
    print(f"Unique drugs: {results_df['drug_name'].nunique()}")
    print(f"\nSample of results:")
    display(results_df.head(20))
else:
    print("No matches found")
# Out:
# Total rows: 152
# Unique drugs: 126
#
# Sample of results:
#              drug_name                                             smiles  \
# 0          Resveratrol                     Oc1ccc(cc1)/C=C/c1cc(O)cc(c1)O
# 1          Resveratrol                     Oc1ccc(cc1)/C=C/c1cc(O)cc(c1)O
# 2           Citalopram    CN(C)CCCC1(C2=C(CO1)C=C(C=C2)C#N)C3=CC=C(C=C3)F
# 3            Gefitinib  COC1=C(C=C2C(=C1)N=CN=C2NC3=CC(=C(C=C3)F)Cl)OC...
# 4            Tretinoin         CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C
# 5    Hypochlorous acid                                                OCl
# 6   4-hydroxytamoxifen  CCC(=C(C1=CC=C(C=C1)O)C2=CC=C(C=C2)OCCN(C)C)C3...
# 7    Mycophenolic acid        CC1=C(C(=C(C2=C1COC2=O)O)CC=C(C)CCC(=O)O)OC
# 8    Mycophenolic acid        CC1=C(C(=C(C2=C1COC2=O)O)CC=C(C)CCC(=O)O)OC
# 9          Abiraterone  O[C@H]1CC[C@]2(C(=CC[C@@H]3[C@@H]2CC[C@]2([C@H...
# 10           Cisplatin                                     N.N.Cl[Pt+2]Cl
# 11           Cisplatin                                     N.N.Cl[Pt+2]Cl
# 12         Azacitidine                 C1=NC(=NC(=O)N1C2C(C(C(O2)CO)O)O)N
# 13        Methotrexate  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 14        Methotrexate  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 15          Decitabine                      C1C(C(OC1N2C=NC(=NC2=O)N)CO)O
# 16            Imatinib  CC1=C(C=C(C=C1)NC(=O)C2=CC=C(C=C2)CN3CCN(CC3)C...
# 17         Doxorubicin  CC1C(C(CC(O1)OC2CC(CC3=C(C4=C(C(=C23)O)C(=O)C5...
# 18         Doxorubicin  CC1C(C(CC(O1)OC2CC(CC3=C(C4=C(C(=C23)O)C(=O)C5...
# 19         Apratoxin a  CCC(C)C1C(=O)N2CCCC2C(=O)OC(CC(CC(C(C3=NC(CS3)...
#
#    regulation_type                                      matched_genes  \
# 0             down            LYZ,CSRP3,SNORD13,SNORD13,SNORD13,CSRP3
# 1               up  RNU1-1,GAPDH,RPL8,RPL8,RNU1-1,GAPDH,GAPDH,RNU1...
# 2               up                                               RPL8
# 3               up                                              GAPDH
# 4             down    SNORD13,LYZ,SNORD13,LYZ,SNORD13,LYZ,LYZ,SNORD13
# 5               up                                               RPL8
# 6               up                                               RPL8
# 7             down                                                LYZ
# 8               up                                              GAPDH
# 9             down                                            SNORD13
# 10            down                                    SNORD13,SNORD13
# 11              up  GAPDH,GAPDH,RNU1-1,RNU1-1,RNU1-1,RNU1-1,GAPDH,...
# 12              up   GAPDH,RPL8,GAPDH,RPL8,RPL8,GAPDH,RPL8,GAPDH,RPL8
# 13            down                                                LYZ
# 14              up                              GAPDH,RPL8,GAPDH,RPL8
# 15              up     RPL8,GAPDH,RPL8,RPL8,RPL8,RPL8,GAPDH,RPL8,RPL8
# 16              up                                   GAPDH,RPL8,GAPDH
# 17            down                                                LYZ
# 18              up  GAPDH,GAPDH,RPL8,RNU1-1,GAPDH,RPL8,GAPDH,GAPDH...
# 19            down                                            LYZ,LYZ
#
#                                     regulation_scores  avg_score  gene_count  \
# 0     -0.2412,-0.1543,-0.1507,-0.1937,-0.1127,-0.0339  -0.147767           6
# 1   0.1403,0.1318,0.1204,0.0357,0.0213,0.0319,0.01...   0.059455           9
# 2                                              0.0138   0.013782           1
# 3                                              0.0191   0.019089           1
# 4   -0.0958,-0.0221,-0.1298,-0.0222,-0.1198,-0.022...  -0.067497           8
# 5                                              0.0534   0.053378           1
# 6                                              0.0319   0.031886           1
# 7                                             -0.0267  -0.026655           1
# 8                                              0.0141   0.014080           1
# 9                                             -0.0352  -0.035187           1
# 10                                    -0.2066,-0.0265  -0.116520           2
# 11  0.0448,0.0227,0.0400,0.0280,0.0329,0.0274,0.07...   0.034495          11
# 12  0.0377,0.1149,0.0207,0.0484,0.0275,0.0331,0.05...   0.045579           9
# 13                                            -0.0485  -0.048470           1
# 14                        0.0322,0.0503,0.0478,0.0338   0.041023           4
# 15  0.0204,0.0310,0.0678,0.0387,0.0443,0.0529,0.03...   0.043758           9
# 16                               0.0104,0.0894,0.0672   0.055667           3
# 17                                            -0.0232  -0.023241           1
# 18  0.0553,0.0285,0.0818,0.0344,0.0171,0.0504,0.02...   0.039373          12
# 19                                    -0.0455,-0.0356  -0.040569           2
#
#                                              drug_ids  \
# 0   drug:3499,drug:3498,drug:3497,drug:3494,drug:3...
# 1   drug:3499,drug:3498,drug:3497,drug:3494,drug:3...
# 2                                           drug:3292
# 3                                           drug:3474
# 4   drug:3233,drug:3232,drug:3231,drug:3237,drug:3...
# 5   drug:3198,drug:3199,drug:3202,drug:3197,drug:3...
# 6                                 drug:3239,drug:3240
# 7                                           drug:3302
# 8                                           drug:3302
# 9                                           drug:3300
# 10  drug:3160,drug:3158,drug:3159,drug:3155,drug:3...
# 11  drug:3160,drug:3158,drug:3159,drug:3155,drug:3...
# 12  drug:2542,drug:2544,drug:2545,drug:2536,drug:2...
# 13  drug:2543,drug:2541,drug:3072,drug:2601,drug:2600
# 14  drug:2543,drug:2541,drug:3072,drug:2601,drug:2600
# 15  drug:2540,drug:2546,drug:2547,drug:2548,drug:2...
# 16  drug:2763,drug:2519,drug:2517,drug:2516,drug:2...
# 17  drug:2723,drug:2721,drug:2641,drug:2720,drug:2...
# 18  drug:2723,drug:2721,drug:2641,drug:2720,drug:2...
# 19  drug:3069,drug:3068,drug:3066,drug:3067,drug:3...
#
#                                            cell_types
# 0   vastus lateralis muscle,PBMC (peripheral blood...
# 1   vastus lateralis muscle,PBMC (peripheral blood...
# 2                                lymphoblastoid cells
# 3                                          PC-3 cells
# 4   NB4 APL 9 acute promyelocytic leukemia cells -...
# 5   AEC (primary airway epithelial cells) -  6 Hou...
# 6   MCF7 breast cancer cells - 100nM,MCF7 breast c...
# 7                                             No Data
# 8                                             No Data
# 9                                             No Data
# 10  OVCAR-8 ovarian carcinoma cell line,C13 ovaria...
# 11  OVCAR-8 ovarian carcinoma cell line,C13 ovaria...
# 12                                         H1299,A549
# 13  HT29,PBMC,HT29 colon adenocarcinoma cell line,...
# 14  HT29,PBMC,HT29 colon adenocarcinoma cell line,...
# 15                          A549,H1299,HepG2,melanoma
# 16  NA,K562 leukemia cell line (II) - 24 Hours,K56...
# 17  NA,MCF-7 BREAST CANCER cell line,MCF-7/ADR,KJD...
# 18  NA,MCF-7 BREAST CANCER cell line,MCF-7/ADR,KJD...
# 19  HT29 colon adenocarcinoma cells (6 Hours follo...

# %% [markdown]
# ## Export Results

# %%
# Save results to CSV
if len(results_df) > 0:
    results_df.to_csv('data/drug_gene_matches_unique.csv', index=False)
    print("Results saved to 'drug_gene_matches_unique.csv'")
# Out:
# Results saved to 'drug_gene_matches_unique.csv'

# %% [markdown]
# ## Summary Statistics

# %%
# Verify each drug has at most 2 rows
if len(results_df) > 0:
    print("\nRows per drug:")
    rows_per_drug = results_df.groupby('drug_name').size()
    print(rows_per_drug.value_counts().sort_index())
# Out:
# Rows per drug:
# 1    100
# 2     26
# Name: count, dtype: int64

# %%
# Summary by regulation type
if len(results_df) > 0:
    print("\nRegulation Type Summary:")
    reg_summary = results_df.groupby('regulation_type').agg({
        'drug_name': 'count',
        'gene_count': 'sum',
        'avg_score': 'mean'
    }).round(4)
    reg_summary.columns = ['drug_count', 'total_genes', 'avg_score']
    display(reg_summary)
# Out:
# Regulation Type Summary:
#                  drug_count  total_genes  avg_score
# regulation_type
# down                     34           56    -0.0492
# up                      118          304     0.0464

# %%
# Top drugs by total gene matches
if len(results_df) > 0:
    print("\nTop 20 Drugs by Total Gene Matches:")
    top_drugs = results_df.groupby('drug_name').agg({
        'gene_count': 'sum',
        'avg_score': 'mean'
    }).round(4).sort_values('gene_count', ascending=False)
    top_drugs.columns = ['total_genes', 'overall_avg_score']
    display(top_drugs.head(20))
# Out:
# Top 20 Drugs by Total Gene Matches:
#                                                     total_genes  \
# drug_name
# Estradiol                                                    17
# Resveratrol                                                  15
# Cisplatin                                                    13
# Doxorubicin                                                  13
# Azacitidine                                                   9
# Mln4924                                                       9
# Decitabine                                                    9
# Nickel                                                        8
# Triiodothyronine-[13c6] hydrochloride (t3 thyro...            8
# Tretinoin                                                     8
# Curcumin                                                      7
# Plx4032                                                       7
# Apratoxin a                                                   7
# 2,2',4,4',5,5'-hexachlorobiphenyl   (pcb-153)                 6
# 4-hydroxynonenal                                              6
# Ethanol                                                       6
# Methotrexate                                                  5
# Trovafloxacin                                                 5
# Etanercept                                                    5
# Carboplatin                                                   5
#
#                                                     overall_avg_score
# drug_name
# Estradiol                                                      0.0172
# Resveratrol                                                   -0.0442
# Cisplatin                                                     -0.0410
# Doxorubicin                                                    0.0081
# Azacitidine                                                    0.0456
# Mln4924                                                        0.0348
# Decitabine                                                     0.0438
# Nickel                                                         0.0074
# Triiodothyronine-[13c6] hydrochloride (t3 thyro...            -0.0017
# Tretinoin                                                     -0.0675
# Curcumin                                                      -0.0091
# Plx4032                                                        0.0387
# Apratoxin a                                                    0.0054
# 2,2',4,4',5,5'-hexachlorobiphenyl   (pcb-153)                  0.0122
# 4-hydroxynonenal                                               0.0540
# Ethanol                                                        0.0048
# Methotrexate                                                  -0.0037
# Trovafloxacin                                                  0.0510
# Etanercept                                                     0.0128
# Carboplatin                                                    0.0600

# %%
# View specific drug's both rows
if len(results_df) > 0:
    print("\nExample: View both rows for a specific drug")
    sample_drug = results_df['drug_name'].iloc[0]
    print(f"\nShowing entries for: {sample_drug}")
    display(results_df[results_df['drug_name'] == sample_drug])
# Out:
# Example: View both rows for a specific drug
#
# Showing entries for: Resveratrol
#      drug_name                          smiles regulation_type  \
# 0  Resveratrol  Oc1ccc(cc1)/C=C/c1cc(O)cc(c1)O            down
# 1  Resveratrol  Oc1ccc(cc1)/C=C/c1cc(O)cc(c1)O              up
#
#                                        matched_genes  \
# 0            LYZ,CSRP3,SNORD13,SNORD13,SNORD13,CSRP3
# 1  RNU1-1,GAPDH,RPL8,RPL8,RNU1-1,GAPDH,GAPDH,RNU1...
#
#                                    regulation_scores  avg_score  gene_count  \
# 0    -0.2412,-0.1543,-0.1507,-0.1937,-0.1127,-0.0339  -0.147767           6
# 1  0.1403,0.1318,0.1204,0.0357,0.0213,0.0319,0.01...   0.059455           9
#
#                                             drug_ids  \
# 0  drug:3499,drug:3498,drug:3497,drug:3494,drug:3...
# 1  drug:3499,drug:3498,drug:3497,drug:3494,drug:3...
#
#                                           cell_types
# 0  vastus lateralis muscle,PBMC (peripheral blood...
# 1  vastus lateralis muscle,PBMC (peripheral blood...

# %% [markdown]
# ## Saving Unique Drugs

# %%
def process_drugs_to_csv(human_drugs):
   
    results = []
    
    for drug in human_drugs:
        drug_name = drug.get('drug_name', 'Unknown')
        smiles = drug.get('smiles', 'N/A')
        cell_type = drug.get('cell_type', 'N/A')
        idx = drug.get('id', 'N/A')
        
        # Down-regulation row
        down_genes = drug.get('down_genes', [])
        if down_genes:
            results.append({
                'drug_name': drug_name,
                'smiles': smiles,
                'cell_type': cell_type,
                'drug_id': idx,
                'regulation_type': 'down',
                'genes': ','.join([gene[0] for gene in down_genes]),
                'scores': ','.join([f"{gene[1]:.4f}" for gene in down_genes]),
                'gene_count': len(down_genes)
            })
        
        # Up-regulation row
        up_genes = drug.get('up_genes', [])
        if up_genes:
            results.append({
                'drug_name': drug_name,
                'smiles': smiles,
                'cell_type': cell_type,
                'drug_id': idx,
                'regulation_type': 'up',
                'genes': ','.join([gene[0] for gene in up_genes]),
                'scores': ','.join([f"{gene[1]:.4f}" for gene in up_genes]),
                'gene_count': len(up_genes)
            })
    
    return results


all_results = process_drugs_to_csv(human_drugs)
all_df = pd.DataFrame(all_results)

print(f"Total rows (all drugs): {len(all_df)}")

# Filter 
unique_df = all_df.drop_duplicates(subset=['drug_name', 'regulation_type'], keep='first')

print(f"Unique rows: {len(unique_df)}")
print(f"Unique drugs: {unique_df['drug_name'].nunique()}")


all_df.to_csv('data/all_drugs.csv', index=False)
unique_df.to_csv('data/unique_drugs.csv', index=False)
# Out:
# Total rows (all drugs): 900
# Unique rows: 346
# Unique drugs: 173
